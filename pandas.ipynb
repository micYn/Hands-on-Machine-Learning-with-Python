# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# #### Pandas Series

# %%
s1 =pd.Series([1,2,3,4,5])
print(type(s1))
s2 = pd.Series(np.arange(5), dtype=np.uint8)
print(s2)
# left column: indices
# right columns: data
# Out:
# <class 'pandas.core.series.Series'>
# 0    0
# 1    1
# 2    2
# 3    3
# 4    4
# dtype: uint8

# %%
arr1 = np.array([1,3,5,7,9], dtype=np.uint8)
s3 = pd.Series(arr1, dtype=np.int16)
print(s3)
# The data type of the series will be considered as the final data type.
# Out:
# 0    1
# 1    3
# 2    5
# 3    7
# 4    9
# dtype: int16

# %%
# To see the values in the series:
print(s3.values)
s3.array
# Out:
# [1 3 5 7 9]
# <NumpyExtensionArray>
# [1, 3, 5, 7, 9]
# Length: 5, dtype: int16

# %%
# To see the index of the series
s3.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
s3.dtype    #shape, size, nbytes, ndim
# Out:
# dtype('int16')

# %% [markdown]
# #### Pandas Dataframes

# %%
# Like tables in databases 
# We can create dataframes from series, Ndarrays, lists, and dictionaries.
# A dictionary:
data = {'city': ['Bangalore', 'Bangalore', 'Bangalore',
                'Mumbai', 'Mumbai', 'Mumbai'],
       'year': [2020, 2021, 2022, 2020, 2021, 2022,],
       'population': [10.0, 10.1, 10.2, 5.2, 5.3, 5.5]}
df1 = pd.DataFrame(data)
print(df1)
# Out:
#         city  year  population
# 0  Bangalore  2020        10.0
# 1  Bangalore  2021        10.1
# 2  Bangalore  2022        10.2
# 3     Mumbai  2020         5.2
# 4     Mumbai  2021         5.3
# 5     Mumbai  2022         5.5

# %%
df1.head()
# Out:
#         city  year  population
# 0  Bangalore  2020        10.0
# 1  Bangalore  2021        10.1
# 2  Bangalore  2022        10.2
# 3     Mumbai  2020         5.2
# 4     Mumbai  2021         5.3

# %%
# Specify the order of columns:
df2 = pd.DataFrame(data, columns=['year','city', 'population'])
print(df2)
# Out:
#    year       city  population
# 0  2020  Bangalore        10.0
# 1  2021  Bangalore        10.1
# 2  2022  Bangalore        10.2
# 3  2020     Mumbai         5.2
# 4  2021     Mumbai         5.3
# 5  2022     Mumbai         5.5

# %% [markdown]
# #### Visualizing the data in DataFrames

# %%
df1 = pd.DataFrame()
df1['A'] = pd.Series(list(range(100)))
df1['B'] = np.random.randn(100,1) # 100x1 matrix filled with random numbers from standard normal distribution
df1
# Out:
#      A         B
# 0    0  0.882927
# 1    1  1.037079
# 2    2 -0.833753
# 3    3 -0.795464
# 4    4 -1.015947
# ..  ..       ...
# 95  95 -0.308052
# 96  96 -1.004005
# 97  97 -1.001038
# 98  98  0.500564
# 99  99 -0.348413
#
# [100 rows x 2 columns]

# %%
# Objects of Pandas data structures call Matplotlib visualization functions like plot(). 
df1.plot(x='A', y='B')
plt.show()

# %%
df2 = pd.DataFrame(np.random.rand(10, 4),
                   columns=['A', 'B', 'C', 'D'])
print(df2[['A']])

df2.plot.bar()
df2.plot.bar(stacked=True)
df2.plot.barh()
plt.show()
# Out:
#           A
# 0  0.833095
# 1  0.346524
# 2  0.597451
# 3  0.999045
# 4  0.732014
# 5  0.768825
# 6  0.287347
# 7  0.956431
# 8  0.806047
# 9  0.434590

# %%
df2.plot.hist(alpha=0.7)    # alpha is the transparency of the plot
df2.plot.hist(stacked = True, alpha=0.7) # better
df2.plot.hist(stacked=True, alpha=0.7, bins=20) # the data will be divided into 20 intervals along the x-axis
                                                # Each bin represents a range of values
plt.show()

# %%
df2.plot.box()
df2.plot.area()
df2.plot.area(stacked=False)
plt.show()

# %%
df = pd.DataFrame({
    'Category1': [3, 2, 5, 7, 6],
    'Category2': [4, 7, 2, 4, 5],
    'Category3': [2, 4, 6, 8, 5]
}, index=[1, 2, 3, 4, 5])

# Plot an area chart
df.plot.area(alpha=0.6)

plt.title('Area Plot Example')
plt.show()
